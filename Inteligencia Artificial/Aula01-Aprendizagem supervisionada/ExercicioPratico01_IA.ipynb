# %% [markdown]
# ## Importação das bibliotecas utilizadas

# %%
from sklearn.datasets import load_iris
from sklearn.naive_bayes import GaussianNB
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 - Carregamento do dataset

# %%
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
df['target'] = df['target'].apply(lambda x: iris.target_names[x])
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## 2 - Gerando uma visualização

# %%
nomes_classes = iris.target_names
nomes_features = iris.feature_names

plt.figure(figsize=(8, 6))

for classe in range(len(nomes_classes)):
    plt.scatter(
        X[y == classe, 2],  # comprimento da pétala
        X[y == classe, 3],  # largura da pétala
        label=nomes_classes[classe]
    )

plt.xlabel(nomes_features[2])
plt.ylabel(nomes_features[3])
plt.title("Dispersão entre comprimento e largura da pétala")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3 - Instanciação do model da classe GaussianNB

# %%
model = GaussianNB()

# %% [markdown]
# ## 4 - Treinamento do modelo com todos os exemplos da base

# %%
xtrain = iris.data       # características das flores (comprimento/sépalas etc.)
ytrain = iris.target
model.fit(xtrain, ytrain)    # rótulos (tipos de flor)
# Out:
# GaussianNB()

# %% [markdown]
# ## 5 - Inserção de 6 predições especificando dados manualmente

# %%
flores_teste = [
    [5.1, 3.5, 1.4, 0.2],
    [6.7, 3.1, 4.7, 1.5],
    [1.2, 2.4, 3.7, 0.5],
    [6.1, 0.5, 3.2, 2.2],
    [5.7, 4.4, 3.1, 3.0],
    [3.2, 1.3, 6.1, 7.4]
]

# Previsão:
predicoes = model.predict(flores_teste)

# Mostra os nomes das classes previstas
nomes_classes = iris.target_names
for i, pred in enumerate(predicoes):
    print(f"Flor {i+1}: {nomes_classes[pred]}")
# Out:
# Flor 1: setosa
# Flor 2: versicolor
# Flor 3: versicolor
# Flor 4: versicolor
# Flor 5: virginica
# Flor 6: virginica
